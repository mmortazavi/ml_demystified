# %%
import re
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
tqdm.pandas()

# %%
from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'GIS')

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geocoder.geocode, min_delay_seconds = 1,   return_value_on_exception = None) 
# adding 1 second padding between calls

# %%
def get_info_from_coordinated(row):

    try:
        location = geocoder.reverse((row.city_GIS_1,	row.city_GIS_2))
        location_flattened = list(pd.json_normalize(location.raw).T.to_dict().values())[0]

        location_flattened_str = " ".join(location_flattened.keys())
        result_postcode = re.findall("postcode", location_flattened_str)

        if result_postcode:
            postcode_geo = location.raw['address']['postcode']
            state_geo = location.raw['address']['state']
            city_geo = location.raw['address']['county']

            return postcode_geo, state_geo, city_geo
        else:
            address_geo = location.address

            location_rev = geocode(address_geo).raw
            postcode_geo = location_rev.raw['address']['postcode']
            state_geo = location_rev.raw['address']['state']
            city_geo = location_rev.raw['address']['county']
            return postcode_geo, state_geo, city_geo

    except Exception as e:
        return None, None, None

# %%
df = pd.read_csv(r"C:\Users\majmo\Git\ml_demystified\projects\gis\gis_data.csv",index_col=0, delimiter=",")
df = df[['city', 'city_GIS_1', 'city_GIS_2']]

# %%
df_sampled = df.sample(frac=0.1)

# %%
# df_sampled[['postcode_geo', "state_geo", "city_geo"]
#            ] = df_sampled.progress_apply(get_info_from_coordinated, axis =1)

# %%
for row in df_sampled.itertuples():
    print(row)
    postcode_geo, state_geo, city_geo = get_info_from_coordinated(row)
    print(postcode_geo, state_geo, city_geo)
# Out:
# Pandas(Index=912, city='الوند', city_GIS_1=36.1885, city_GIS_2=50.058972)
# None None None
# Pandas(Index=4108, city='اقبالیه', city_GIS_1=36.230583, city_GIS_2=49.923722)
# None None None
# Pandas(Index=599, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=505, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=4026, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=6522, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=1770, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=4545, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=5433, city='تاکستان', city_GIS_1=36.069361, city_GIS_2=49.694056)
# None None None
# Pandas(Index=5327, city='تاکستان', city_GIS_1=36.069361, city_GIS_2=49.694056)
# None None None
# Pandas(Index=3701, city='معلم کلایه', city_GIS_1=36.45125, city_GIS_2=50.478)
# None None None
# Pandas(Index=404, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=2957, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=5195, city='تاکستان', city_GIS_1=36.069361, city_GIS_2=49.694056)
# None None None
# Pandas(Index=3268, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=5680, city='ارداق', city_GIS_1=36.054028, city_GIS_2=49.826194)
# None None None
# Pandas(Index=4910, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=3184, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=3543, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=1980, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=1697, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=6055, city='آوج', city_GIS_1=35.579889, city_GIS_2=49.222306)
# None None None
# Pandas(Index=3084, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=6027, city='محمودآبادنمونه', city_GIS_1=36.292306, city_GIS_2=49.899778)
# None None None
# Pandas(Index=3135, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=4132, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=6372, city='شال', city_GIS_1=35.898278, city_GIS_2=49.767889)
# None None None
# Pandas(Index=3093, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=4746, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=763, city='دانسفهان', city_GIS_1=35.812444, city_GIS_2=49.742722)
# None None None
# Pandas(Index=1988, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=2447, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=4807, city='اقبالیه', city_GIS_1=36.230583, city_GIS_2=49.923722)
# None None None
# Pandas(Index=6597, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=6743, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=1239, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=5545, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=4126, city='اقبالیه', city_GIS_1=36.230583, city_GIS_2=49.923722)
# None None None
# Pandas(Index=2292, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=1729, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=4191, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=744, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=6724, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=3970, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=170, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=4158, city='اقبالیه', city_GIS_1=36.230583, city_GIS_2=49.923722)
# None None None
# Pandas(Index=5647, city='محمودآبادنمونه', city_GIS_1=36.292306, city_GIS_2=49.899778)
# None None None
# Pandas(Index=4374, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=3091, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=5894, city='محمودآبادنمونه', city_GIS_1=36.292306, city_GIS_2=49.899778)
# None None None
# Pandas(Index=5953, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=5360, city='تاکستان', city_GIS_1=36.069361, city_GIS_2=49.694056)
# None None None
# Pandas(Index=4891, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=4805, city='آبیک', city_GIS_1=36.044611, city_GIS_2=50.533694)
# None None None
# Pandas(Index=311, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا
# Pandas(Index=6386, city='آوج', city_GIS_1=35.579889, city_GIS_2=49.222306)
# None None None
# Pandas(Index=6016, city='آوج', city_GIS_1=35.579889, city_GIS_2=49.222306)
# None None None
# Pandas(Index=1926, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=1404, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=1723, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=3490, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=5947, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=1530, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=2439, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=2671, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=2843, city='مجموعه شهری مهرگان', city_GIS_1=36.252528, city_GIS_2=50.182917)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=6412, city='قزوین', city_GIS_1=36.288528, city_GIS_2=50.007111)
# 34139-64347 استان قزوین شهرستان قزوین
# Pandas(Index=2329, city='محمدیه', city_GIS_1=36.223528, city_GIS_2=50.182528)
# 34917-45167 استان قزوین شهرستان البرز
# Pandas(Index=612, city='بوئین زهرا', city_GIS_1=35.76775, city_GIS_2=50.057667)
# 34517-33461 استان قزوین شهرستان بوئین زهرا

# %%
# import the plotly express
import plotly.express as px

# set up the chart from the df dataFrame
fig = px.scatter_geo(df,
                     # longitude is taken from the df["lon"] columns and latitude from df["lat"]
                     lon="city_GIS_1",
                     lat="city_GIS_2",
                     # choose the map chart's projection
                     projection="natural earth",
                     # columns which is in bold in the pop up
                     hover_name="city",
                     # format of the popup not to display these columns' data
                     hover_data={"city": False,
                                 "city_GIS_1": False,
                                 "city_GIS_2": False
                                 }
                     )


# scatter_geo allow to change the map date based on the information from the df dataframe, but we can separately specify the values that are common to all
# change the size of the markers to 25 and color to red
fig.update_traces(marker=dict(size=2, color="red"))

# fit the map to surround the points
fig.update_geos(fitbounds="locations", showcountries=True)

# add title
fig.update_layout(
    title='Your customers'
)
fig.show()
