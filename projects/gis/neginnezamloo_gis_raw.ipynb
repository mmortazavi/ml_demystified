# %%
#Library loading
import pandas as pd

# %%
#reading data
df=pd.read_excel('https://github.com/mmortazavi/ml_demystified/raw/main/projects/gis/raw_data.xlsx') 
df
# Out:
#            نام نام خانوادگی      کد ملی      موبایل  \
# 0          حسن        گروسی  5098674451  9196177092
# 1        مرتضی   حاجی حسینی  4390754092  9032353898
# 2        رحمان        رفیعی  4391615207  9919248418
# 3     ابوالفضل        احمدی  5098799899  9127884216
# 4         جعفر   برزگراحمدی  5099580238  9368960462
# ...        ...          ...         ...         ...
# 6894      صادق    صادقی راد  4380317031  9304338613
# 6895      بهمن       گنج ها  4310661378  9302332570
# 6896      زهرا        امانی  4324466017  9197421004
# 6897      مجید        عسگری  4323123175  9128832897
# 6898      لیلا     مهرعلیان  4390366726  9905539385
#
#                     مرحله ثبت نام شهر مورد تقاضا شهر محل سکونت  \
# 0                           فاز 2     بوئین زهرا    بوئین زهرا
# 1                           فاز 2     بوئین زهرا    بوئین زهرا
# 2                           فاز 2     بوئین زهرا    بوئین زهرا
# 3                           فاز 2     بوئین زهرا    بوئین زهرا
# ...
