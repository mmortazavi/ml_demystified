# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def Urbach_energy(E_min,E_max):
  Wavelength = data['Wavelength']
  Absorption = data['Absorption']
  Energy = 1240/Wavelength
  alpha = Absorption/(5*10**-6)
  ln_alpha = np.log(alpha)
  urbach_region = (Energy >= E_min) & (Energy <= E_max)
  slope, intercept = np.polyfit(Energy[urbach_region], ln_alpha[urbach_region],1)
  urbach_energy = 1/slope
  #Plot
  x = Energy
  y = np.log(alpha)
  x_min = 2
  x_max = 3
  filter_x = x[(x >= x_min) & (x <= x_max)]
  filter_y = y[(x >= x_min) & (x <= x_max)]
  plt.plot(filter_x, filter_y)
  plt.xlabel("Energy (ev)")
  plt.ylabel("ln_alpha")
  print("Urbach energy:", urbach_energy, "eV")

# %%
#sample1
data = pd.read_csv("/content/Sample1.csv")
Urbach_energy(2.05,2.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Urbach energy: 0.17971563502679805 eV

# %%
#sample2
data = pd.read_csv("/content/Sample2.csv")
Urbach_energy(2.05,2.3)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Urbach energy: 0.32002580788949697 eV

# %%
#sample3
data = pd.read_csv("/content/Sample3.csv")
Urbach_energy(2.2,2.4)
# Out:
# Urbach energy: 0.3174092459224033 eV

# %%
#Sample4
data = pd.read_csv("/content/Sample4.csv")
Urbach_energy(2.2,2.4)
# Out:
# Urbach energy: 0.2756862534518112 eV

# %%
#Sample5
data = pd.read_csv("/content/Sample5.csv")
Urbach_energy(2.2,2.4)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Urbach energy: 0.33962258666673084 eV

# %%
Sample = ['Sample1','Sample2','Sample3','Sample4','Sample5']
Urbach_energy = [0.1797,0.3200,0.3174,0.2756,0.3396]
UE = pd.DataFrame({
    'Sample': Sample,
    'Urbach energy(ev)': Urbach_energy})
UE
# Out:
#     Sample  Urbach energy(ev)
# 0  Sample1             0.1797
# 1  Sample2             0.3200
# 2  Sample3             0.3174
# 3  Sample4             0.2756
# 4  Sample5             0.3396
