# %% [markdown]
# The energy difference that is present between the top of the valence band and the bottom of the conduction band

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d44615f-d5ea-46c9-b5d3-620689c38820" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d44615f-d5ea-46c9-b5d3-620689c38820">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def Bandgap():
  df_filtered = data[data['Intensity'] < 420]
  wavelength = df_filtered["Wavelength"]
  intensity = df_filtered["Intensity"]
  #Calculate Bandgap
  max_wavelength = intensity[wavelength.idxmax()]
  band_gap = 1240 / max_wavelength
  #plot first peak
  plt.plot(intensity,wavelength)
  plt.xlabel("Wavelength (nm)")
  plt.ylabel("Intensity (a.u.)")
  plt.xlim([350, 420])
  plt.show()
  #print Bandgap
  print("Wavelength:",max_wavelength,"nm")
  print("Band gap:", band_gap, "eV")

# %%
#Sample1
data = pd.read_csv("/content/Sample1_pl.csv")
Bandgap()
# Out:
# Wavelength: 382.5 nm
# Band gap: 3.241830065359477 eV

# %%
#Sample2
data = pd.read_csv("/content/Sample2_pl.csv")
Bandgap()
# Out:
# Wavelength: 381.5 nm
# Band gap: 3.250327653997379 eV

# %%
#Sample3
data = pd.read_csv("/content/Sample3_pl.csv")
Bandgap()
# Out:
# Wavelength: 388.0 nm
# Band gap: 3.195876288659794 eV

# %%
#Sample4
data = pd.read_csv("/content/Sample4_pl.csv")
Bandgap()
# Out:
# Wavelength: 381.0 nm
# Band gap: 3.254593175853018 eV

# %%
#Sample5
data = pd.read_csv("/content/Sample5_pl.csv")
Bandgap()
# Out:
# Wavelength: 386.5 nm
# Band gap: 3.2082794307891334 eV

# %%
Sample = ['Sample1','Sample2','Sample3','Sample4','Sample5']
Wavelength = [382.5,381.5,388.0,381.0,386.5]
bandgap = [3.2418,3.2503,3.1958,3.2545,3.2082]
Pl = pd.DataFrame({
    'Sample': Sample,
    'Wavelength(nm)': Wavelength ,
    'Bandgap(ev)': bandgap})
Pl
# Out:
#     Sample  Wavelength(nm)  Bandgap(ev)
# 0  Sample1           382.5       3.2418
# 1  Sample2           381.5       3.2503
# 2  Sample3           388.0       3.1958
# 3  Sample4           381.0       3.2545
# 4  Sample5           386.5       3.2082
