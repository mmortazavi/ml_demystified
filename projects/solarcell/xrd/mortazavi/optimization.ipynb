# %%
#Importing necessary libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction

from pycaret.regression import *

# %%
#Encoding method 1
df = pd.read_excel(r'xrd_new.xlsx', sheet_name='Sheet6')
df = df.drop(['Isc','schw 1', 'schw 2','schw 3', 'schw 4', 'schw 5', 'schw 6'], axis=1)

# %%
reg = setup(data=df , target = 'FF' ,normalize=True , normalize_method='minmax',train_size=0.8,fold=3
            ,keep_features=['FWHM 1', 'FWHM 2', 'FWHM 3', 'FWHM 4', 'FWHM 5',
            'FWHM 6', '2-theta 1', '2-theta 2', '2-theta 3', '2-theta 4',
            '2-theta 5', '2-theta 6','relative_intensity 1',
            'relative_intensity 2', 'relative_intensity 3', 'relative_intensity 4',
            'relative_intensity 5', 'relative_intensity 6']
            ,remove_multicollinearity = True, multicollinearity_threshold= 0.9
            , session_id=1543)
# Out:
# <style type="text/css">
# #T_72698_row9_col1, #T_72698_row13_col1, #T_72698_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_72698_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72698_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72698_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_72698_row0_col1" class="data row0 col1" >1543</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72698_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_72698_row1_col1" class="data row1 col1" >FF</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72698_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_72698_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72698_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_72698_row3_col1" class="data row3 col1" >(27, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72698_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_72698_row4_col1" class="data row4 col1" >(27, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72698_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_72698_row5_col1" class="data row5 col1" >(21, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72698_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_72698_row6_col1" class="data row6 col1" >(6, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72698_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_72698_row7_col1" class="data row7 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72698_row8_col0" class="data row8 col0" >Keep features</td>
#       <td id="T_72698_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72698_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_72698_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_72698_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_72698_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_72698_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_72698_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_72698_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_72698_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_72698_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_72698_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_72698_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_72698_row14_col1" class="data row14 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_72698_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_72698_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_72698_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_72698_row16_col1" class="data row16 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_72698_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_72698_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_72698_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_72698_row18_col1" class="data row18 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_72698_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_72698_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_72698_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_72698_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_72698_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_72698_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_72698_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_72698_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_72698_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_72698_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_72698_row23_col1" class="data row23 col1" >4cca</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import RandomForestRegressor from sklearn
best = compare_models(cross_validation=False)
# Out:
# <style type="text/css">
# #T_2a988_ th {
#   text-align: left;
# }
# #T_2a988_row0_col0, #T_2a988_row1_col0, #T_2a988_row1_col1, #T_2a988_row1_col2, #T_2a988_row1_col3, #T_2a988_row1_col4, #T_2a988_row1_col5, #T_2a988_row1_col6, #T_2a988_row2_col0, #T_2a988_row2_col1, #T_2a988_row2_col2, #T_2a988_row2_col3, #T_2a988_row2_col4, #T_2a988_row2_col5, #T_2a988_row2_col6, #T_2a988_row3_col0, #T_2a988_row3_col1, #T_2a988_row3_col2, #T_2a988_row3_col3, #T_2a988_row3_col4, #T_2a988_row3_col5, #T_2a988_row3_col6, #T_2a988_row4_col0, #T_2a988_row4_col1, #T_2a988_row4_col2, #T_2a988_row4_col3, #T_2a988_row4_col4, #T_2a988_row4_col5, #T_2a988_row4_col6, #T_2a988_row5_col0, #T_2a988_row5_col1, #T_2a988_row5_col2, #T_2a988_row5_col3, #T_2a988_row5_col4, #T_2a988_row5_col5, #T_2a988_row5_col6, #T_2a988_row6_col0, #T_2a988_row6_col1, #T_2a988_row6_col2, #T_2a988_row6_col3, #T_2a988_row6_col4, #T_2a988_row6_col5, #T_2a988_row6_col6, #T_2a988_row7_col0, #T_2a988_row7_col1, #T_2a988_row7_col2, #T_2a988_row7_col3, #T_2a988_row7_col4, #T_2a988_row7_col5, #T_2a988_row7_col6, #T_2a988_row8_col0, #T_2a988_row8_col1, #T_2a988_row8_col2, #T_2a988_row8_col3, #T_2a988_row8_col4, #T_2a988_row8_col5, #T_2a988_row8_col6, #T_2a988_row9_col0, #T_2a988_row9_col1, #T_2a988_row9_col2, #T_2a988_row9_col3, #T_2a988_row9_col4, #T_2a988_row9_col5, #T_2a988_row9_col6, #T_2a988_row10_col0, #T_2a988_row10_col1, #T_2a988_row10_col2, #T_2a988_row10_col3, #T_2a988_row10_col4, #T_2a988_row10_col5, #T_2a988_row10_col6, #T_2a988_row11_col0, #T_2a988_row11_col1, #T_2a988_row11_col2, #T_2a988_row11_col3, #T_2a988_row11_col4, #T_2a988_row11_col5, #T_2a988_row11_col6, #T_2a988_row12_col0, #T_2a988_row12_col1, #T_2a988_row12_col2, #T_2a988_row12_col3, #T_2a988_row12_col4, #T_2a988_row12_col5, #T_2a988_row12_col6, #T_2a988_row13_col0, #T_2a988_row13_col1, #T_2a988_row13_col2, #T_2a988_row13_col3, #T_2a988_row13_col4, #T_2a988_row13_col5, #T_2a988_row13_col6, #T_2a988_row14_col0, #T_2a988_row14_col1, #T_2a988_row14_col2, #T_2a988_row14_col3, #T_2a988_row14_col4, #T_2a988_row14_col5, #T_2a988_row14_col6, #T_2a988_row15_col0, #T_2a988_row15_col1, #T_2a988_row15_col2, #T_2a988_row15_col3, #T_2a988_row15_col4, #T_2a988_row15_col5, #T_2a988_row15_col6, #T_2a988_row16_col0, #T_2a988_row16_col1, #T_2a988_row16_col2, #T_2a988_row16_col3, #T_2a988_row16_col4, #T_2a988_row16_col5, #T_2a988_row16_col6, #T_2a988_row17_col0, #T_2a988_row17_col1, #T_2a988_row17_col2, #T_2a988_row17_col3, #T_2a988_row17_col4, #T_2a988_row17_col5, #T_2a988_row17_col6, #T_2a988_row18_col0, #T_2a988_row18_col1, #T_2a988_row18_col2, #T_2a988_row18_col3, #T_2a988_row18_col4, #T_2a988_row18_col5, #T_2a988_row18_col6, #T_2a988_row19_col0, #T_2a988_row19_col1, #T_2a988_row19_col2, #T_2a988_row19_col3, #T_2a988_row19_col4, #T_2a988_row19_col5, #T_2a988_row19_col6 {
#   text-align: left;
# }
# #T_2a988_row0_col1, #T_2a988_row0_col2, #T_2a988_row0_col3, #T_2a988_row0_col4, #T_2a988_row0_col5, #T_2a988_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2a988_row0_col7, #T_2a988_row1_col7, #T_2a988_row2_col7, #T_2a988_row3_col7, #T_2a988_row4_col7, #T_2a988_row5_col7, #T_2a988_row6_col7, #T_2a988_row11_col7, #T_2a988_row13_col7, #T_2a988_row14_col7, #T_2a988_row16_col7, #T_2a988_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2a988_row7_col7, #T_2a988_row8_col7, #T_2a988_row9_col7, #T_2a988_row10_col7, #T_2a988_row12_col7, #T_2a988_row15_col7, #T_2a988_row18_col7, #T_2a988_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2a988_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a988_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_2a988_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_2a988_row0_col1" class="data row0 col1" >0.4405</td>
#       <td id="T_2a988_row0_col2" class="data row0 col2" >0.3105</td>
#       <td id="T_2a988_row0_col3" class="data row0 col3" >0.5573</td>
#       <td id="T_2a988_row0_col4" class="data row0 col4" >0.9556</td>
#       <td id="T_2a988_row0_col5" class="data row0 col5" >0.0120</td>
#       <td id="T_2a988_row0_col6" class="data row0 col6" >0.0099</td>
#       <td id="T_2a988_row0_col7" class="data row0 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_2a988_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_2a988_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#       <td id="T_2a988_row1_col1" class="data row1 col1" >0.6857</td>
#       <td id="T_2a988_row1_col2" class="data row1 col2" >0.9939</td>
#       <td id="T_2a988_row1_col3" class="data row1 col3" >0.9969</td>
#       <td id="T_2a988_row1_col4" class="data row1 col4" >0.8580</td>
#       <td id="T_2a988_row1_col5" class="data row1 col5" >0.0232</td>
#       <td id="T_2a988_row1_col6" class="data row1 col6" >0.0159</td>
#       <td id="T_2a988_row1_col7" class="data row1 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_2a988_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_2a988_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2a988_row2_col1" class="data row2 col1" >0.7718</td>
#       <td id="T_2a988_row2_col2" class="data row2 col2" >1.0272</td>
#       <td id="T_2a988_row2_col3" class="data row2 col3" >1.0135</td>
#       <td id="T_2a988_row2_col4" class="data row2 col4" >0.8532</td>
#       <td id="T_2a988_row2_col5" class="data row2 col5" >0.0223</td>
#       <td id="T_2a988_row2_col6" class="data row2 col6" >0.0175</td>
#       <td id="T_2a988_row2_col7" class="data row2 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_2a988_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_2a988_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_2a988_row3_col1" class="data row3 col1" >0.9582</td>
#       <td id="T_2a988_row3_col2" class="data row3 col2" >1.1494</td>
#       <td id="T_2a988_row3_col3" class="data row3 col3" >1.0721</td>
#       <td id="T_2a988_row3_col4" class="data row3 col4" >0.8357</td>
#       <td id="T_2a988_row3_col5" class="data row3 col5" >0.0242</td>
#       <td id="T_2a988_row3_col6" class="data row3 col6" >0.0224</td>
#       <td id="T_2a988_row3_col7" class="data row3 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_2a988_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_2a988_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_2a988_row4_col1" class="data row4 col1" >0.8802</td>
#       <td id="T_2a988_row4_col2" class="data row4 col2" >1.1775</td>
#       <td id="T_2a988_row4_col3" class="data row4 col3" >1.0851</td>
#       <td id="T_2a988_row4_col4" class="data row4 col4" >0.8317</td>
#       <td id="T_2a988_row4_col5" class="data row4 col5" >0.0257</td>
#       <td id="T_2a988_row4_col6" class="data row4 col6" >0.0212</td>
#       <td id="T_2a988_row4_col7" class="data row4 col7" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_2a988_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_2a988_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_2a988_row5_col1" class="data row5 col1" >1.2853</td>
#       <td id="T_2a988_row5_col2" class="data row5 col2" >1.7930</td>
#       <td id="T_2a988_row5_col3" class="data row5 col3" >1.3390</td>
#       <td id="T_2a988_row5_col4" class="data row5 col4" >0.7437</td>
#       <td id="T_2a988_row5_col5" class="data row5 col5" >0.0307</td>
#       <td id="T_2a988_row5_col6" class="data row5 col6"

# %%
# the coefficient of determination of the prediction.
model = create_model('gbr',cross_validation = False, return_train_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0c88_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0c88_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_b0c88_row0_col0" class="data row0 col0" >0.4405</td>
#       <td id="T_b0c88_row0_col1" class="data row0 col1" >0.3105</td>
#       <td id="T_b0c88_row0_col2" class="data row0 col2" >0.5573</td>
#       <td id="T_b0c88_row0_col3" class="data row0 col3" >0.9556</td>
#       <td id="T_b0c88_row0_col4" class="data row0 col4" >0.0120</td>
#       <td id="T_b0c88_row0_col5" class="data row0 col5" >0.0099</td>
#     </tr>
#     <tr>
#       <th id="T_b0c88_level0_row1" class="row_heading level0 row1" >Train</th>
#       <td id="T_b0c88_row1_col0" class="data row1 col0" >0.1101</td>
#       <td id="T_b0c88_row1_col1" class="data row1 col1" >0.0207</td>
#       <td id="T_b0c88_row1_col2" class="data row1 col2" >0.1438</td>
#       <td id="T_b0c88_row1_col3" class="data row1 col3" >0.9960</td>
#       <td id="T_b0c88_row1_col4" class="data row1 col4" >0.0033</td>
#       <td id="T_b0c88_row1_col5" class="data row1 col5" >0.0025</td>
#     </tr>
#   </tbody>
# </table>

# %%
def wrapper(X, Y, **kwargs) -> float:
    
    input = np.array([[X, Y]])
    output = model.predict(input, **kwargs)
    output = float(output)

    if (output > -1) & (output < 10):
        return output
    
    else:
        return 10000000

# %%
def optimizer_instantiate(df, wrapper, pbounds, n_iter=10, kappa=5, xi=None, random_state=None):

    # df.plot(kind='scatter', x='X', y='Y', c='Z', cmap='plasma', figsize=(6,5))
    optimizer  = BayesianOptimization(wrapper, pbounds, verbose=2)

    # bo.maximize(init_points=2, n_iter=n_iter, acq='ucb', kappa=kappa)
    # plt.plot(bo.max["params"]["X"],bo.max["params"]["Y"], '*', markersize=10)
    # plt.show()
    utility = UtilityFunction(kind="ucb", kappa=kappa, xi=0)

    return optimizer, utility


def optimizer_suggest(optimizer, utility):
 
    next_point_to_probe = optimizer .suggest(utility)
    print(f"Next Point to Probe: {next_point_to_probe}")
    return next_point_to_probe

# %%
features = df.drop(columns=["FF"]).columns.to_list()

pbounds = {feature: (df[feature].min(), df[feature].max()) for feature in features}
# print(f"pbounds: {pbounds}")
# pbounds = {'X': (-5.0, 4.0), 'Y': (-3.0, 7.0)}
optimizer, utility = optimizer_instantiate(df, wrapper, pbounds, n_iter=100, kappa=10, xi=None, random_state=None)

# %%
next_point_to_probe = optimizer_suggest(optimizer, utility)
target = model.predict(pd.DataFrame(next_point_to_probe, index=[0]).values.reshape(1, -1))
print("Found the target value to be:", target)
# Out:
# Next Point to Probe: {'2-theta 1': 32.169719241042166, '2-theta 2': 34.86210606047435, '2-theta 3': 36.855714101294446, '2-theta 4': 48.17677884950854, '2-theta 5': 57.03732307628229, '2-theta 6': 63.882621700411946, 'DROP': 4.658364527437871, 'FWHM 1': 0.2598346020008028, 'FWHM 2': 0.2222909083560184, 'FWHM 3': 0.3840079441555695, 'FWHM 4': 0.5517406986414133, 'FWHM 5': 0.5853122699683866, 'FWHM 6': 0.7368625585160986, 'Intensity 1': 0.72404095111281, 'Intensity 2': 0.5320828146801186, 'Intensity 3': 0.8755959186171596, 'Intensity 4': 0.16963394663976325, 'Intensity 5': 0.26179532771277125, 'Intensity 6': 0.20687731864291004, 'relative_intensity 1': 92.01941540054008, 'relative_intensity 2': 38.41842270823152, 'relative_intensity 3': 79.93848962318741, 'relative_intensity 4': 15.565793340323244, 'relative_intensity 5': 16.64167379687857, 'relative_intensity 6': 17.621577518585088}
# Found the target value to be: [43.50669067]

# %%
optimizer.register(
    params=next_point_to_probe,
    target=target[0],
)

# %%
for _ in range(6):
    next_point = optimizer.suggest(utility)
    target = model.predict(pd.DataFrame(next_point, index=[0]).values.reshape(1, -1))
    optimizer.register(params=next_point, target=target[0])
    
    print(target, next_point)
    print()
print(optimizer.max)
# Out:
# [43.79884942] {'2-theta 1': 32.09, '2-theta 2': 34.81, '2-theta 3': 36.69, '2-theta 4': 48.29, '2-theta 5': 57.01, '2-theta 6': 63.89, 'DROP': 1.0, 'FWHM 1': 0.45, 'FWHM 2': 0.17, 'FWHM 3': 0.23, 'FWHM 4': 0.24, 'FWHM 5': 0.3, 'FWHM 6': 0.25, 'Intensity 1': 0.95, 'Intensity 2': 0.34, 'Intensity 3': 1.0, 'Intensity 4': 0.13, 'Intensity 5': 0.43, 'Intensity 6': 0.15, 'relative_intensity 1': 100.0, 'relative_intensity 2': 62.1, 'relative_intensity 3': 78.94, 'relative_intensity 4': 13.68, 'relative_intensity 5': 43.0, 'relative_intensity 6': 23.07}
#
# [43.49836066] {'2-theta 1': 32.09, '2-theta 2': 34.9, '2-theta 3': 36.86, '2-theta 4': 48.29, '2-theta 5': 57.42, '2-theta 6': 63.69, 'DROP': 1.0, 'FWHM 1': 0.45, 'FWHM 2': 0.39, 'FWHM 3': 0.52, 'FWHM 4': 0.73, 'FWHM 5': 0.74, 'FWHM 6': 0.925902394, 'Intensity 1': 0.5, 'Intensity 2': 0.34, 'Intensity 3': 1.0, 'Intensity 4': 0.19, 'Intensity 5': 0.1, 'Intensity 6': 0.23, 'relative_intensity 1': 100.0, 'relative_intensity 2': 38.2, 'relative_intensity 3': 100.0, 'relative_intensity 4': 20.0, 'relative_intensity 5': 43.0, 'relative_intensity 6': 15.78}
#
# [43.52057151] {'2-theta 1': 32.09, '2-theta 2': 34.81, '2-theta 3': 36.69, '2-theta 4': 48.29, '2-theta 5': 57.42, '2-theta 6': 63.89, 'DROP': 6.0, 'FWHM 1': 0.19, 'FWHM 2': 0.17, 'FWHM 3': 0.23, 'FWHM 4': 0.24, 'FWHM 5': 0.3, 'FWHM 6': 0.925902394, 'Intensity 1': 0.5, 'Intensity 2': 0.59, 'Intensity 3': 1.0, 'Intensity 4': 0.13, 'Intensity 5': 0.43, 'Intensity 6': 0.15, 'relative_intensity 1': 74.61631170258879, 'relative_intensity 2': 62.1, 'relative_intensity 3': 100.0, 'relative_intensity 4': 20.0, 'relative_intensity 5': 10.52, 'relative_intensity 6': 23.07}
#
# [43.79929981] {'2-theta 1': 32.25, '2-theta 2': 34.9, '2-theta 3': 36.86, '2-theta 4': 48.29, '2-theta 5': 57.01, '2-theta 6': 63.89, 'DROP': 1.0, 'FWHM 1': 0.45, 'FWHM 2': 0.39, 'FWHM 3': 0.52, 'FWHM 4': 0.24, 'FWHM 5': 0.3, 'FWHM 6': 0.25, 'Intensity 1': 0.95, 'Intensity 2': 0.34, 'Intensity 3': 0.75, 'Intensity 4': 0.13, 'Intensity 5': 0.1, 'Intensity 6': 0.23, 'relative_intensity 1': 60.0, 'relative_intensity 2': 39.1666054179716, 'relative_intensity 3': 78.94, 'relative_intensity 4': 13.68, 'relative_intensity 5': 10.52, 'relative_intensity 6': 23.07}
#
# [43.79884942] {'2-theta 1': 32.25, '2-theta 2': 34.81, '2-theta 3': 36.86, '2-theta 4': 48.29, '2-theta 5': 57.42, '2-theta 6': 63.69, 'DROP': 6.0, 'FWHM 1': 0.19, 'FWHM 2': 0.39, 'FWHM 3': 0.23, 'FWHM 4': 0.24, 'FWHM 5': 0.74, 'FWHM 6': 0.25, 'Intensity 1': 0.95, 'Intensity 2': 0.59, 'Intensity 3': 0.75, 'Intensity 4': 0.19, 'Intensity 5': 0.43, 'Intensity 6': 0.23, 'relative_intensity 1': 76.663912375028, 'relative_intensity 2': 62.1, 'relative_intensity 3': 78.94, 'relative_intensity 4': 13.68, 'relative_intensity 5': 43.0, 'relative_intensity 6': 23.07}
#
# [43.52057151] {'2-theta 1': 32.09, '2-theta 2': 34.9, '2-theta 3': 36.86, '2-theta 4': 48.16, '2-theta 5': 57.42, '2-theta 6': 63.89, 'DROP': 1.0, 'FWHM 1': 0.45, 'FWHM 2': 0.39, 'FWHM 3': 0.23, 'FWHM 4': 0.24, 'FWHM 5': 0.74, 'FWHM 6': 0.925902394, 'Intensity 1': 0.5, 'Intensity 2': 0.59, 'Intensity 3': 0.75, 'Intensity 4': 0.13, 'Intensity 5': 0.43, 'Intensity 6': 0.15, 'relative_intensity 1': 100.0, 'relative_intensity 2': 62.1, 'relative_intensity 3': 78.94, 'relative_intensity 4': 20.0, 'relative_intensity 5': 10.52, 'relative_intensity 6': 23.07}
#
# {'target': 43.799299814070594, 'params': {'2-theta 1': 32.25, '2-theta 2': 34.9, '2-theta 3': 36.86, '2-theta 4': 48.29, '2-theta 5': 57.01, '2-theta 6': 63.89, 'DROP': 1.0, 'FWHM 1': 0.45, 'FWHM 2': 0.39, 'FWHM 3': 0.52, 'FWHM 4': 0.24, 'FWHM 5': 0.3, 'FWHM 6': 0.25, 'Intensity 1': 0.95, 'Intensity 2': 0.34, 'Intensity 3': 0.75, 'Intensity 4': 0.13, 'Intensity 5': 0.1, 'Intensity 6': 0.23, 'relative_intensity 1': 60.0, 'relative_intensity 2': 39.1666054179716, 'relative_intensity 3': 78.94, 'relative_intensity 4': 13.68, 'relative_intensity 5': 10.52, 'relative_intensity 6': 23.07}}

# %% [markdown]
# ### References
# - https://github.com/bayesian-optimization/BayesianOptimization/blob/master/examples/advanced-tour.ipynb
# - https://github.com/bayesian-optimization/BayesianOptimization/blob/master/examples/exploitation_vs_exploration.ipynb
